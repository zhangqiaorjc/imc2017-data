# %%
import numpy as np
import matplotlib

import matplotlib.pyplot as plt
from __future__ import unicode_literals

# %%
# load data
web_burst_span_plot_matrix = np.loadtxt("fig3_burst_dur_web.csv", delimiter=",")
cache_burst_span_plot_matrix = np.loadtxt("fig3_burst_dur_cache.csv", delimiter=",")
hadoop_burst_span_plot_matrix = np.loadtxt("fig3_burst_dur_hadoop.csv", delimiter=",")

# plot
fig, ax = plt.subplots(linewidth=2)

ax.plot(web_burst_span_plot_matrix[:,0], web_burst_span_plot_matrix[:,1], color="r", label="Web")
ax.plot(cache_burst_span_plot_matrix[:,0], cache_burst_span_plot_matrix[:,1], color="g", label="Cache")
ax.plot(hadoop_burst_span_plot_matrix[:,0], hadoop_burst_span_plot_matrix[:,1], color="b", label="Hadoop")

plt.xlim((0,500))
plt.xlabel("Burst Duration (μs)")
plt.ylabel("CDF")

plt.legend(loc=4)

ax.get_xaxis().set_visible(True)
ax.get_yaxis().set_visible(True)
ax.xaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)
ax.set_facecolor('white')

fig.set_size_inches(6, 3.5)

# %%
# load data
web_nonburst_span_plot_matrix = np.loadtxt("fig4_interburst_dur_web.csv", delimiter=",")
cache_nonburst_span_plot_matrix = np.loadtxt("fig4_interburst_dur_cache.csv", delimiter=",")
hadoop_nonburst_span_plot_matrix = np.loadtxt("fig4_interburst_dur_hadoop.csv", delimiter=",")

# plot
fig, ax = plt.subplots(linewidth=2)

ax.semilogx(web_nonburst_span_plot_matrix[:,0], web_nonburst_span_plot_matrix[:,1], color="r", label="Web")
ax.semilogx(cache_nonburst_span_plot_matrix[:,0], cache_nonburst_span_plot_matrix[:,1], color="g", label="Cache")
ax.semilogx(hadoop_nonburst_span_plot_matrix[:,0], hadoop_nonburst_span_plot_matrix[:,1], color="b", label="Hadoop")

plt.xlim((0,100))
plt.xlabel("Inter-burst Duration (ms)")
plt.ylabel("CDF")

plt.legend(loc=4)

ax.get_xaxis().set_visible(True)
ax.get_yaxis().set_visible(True)
ax.xaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)
ax.set_facecolor('white')

fig.set_size_inches(6, 3.5)

# %%
# load data
web_data_r_plot_matrix = np.loadtxt("fig6_link_util_web.csv", delimiter=",")
cache_data_r_plot_matrix = np.loadtxt("fig6_link_util_cache.csv", delimiter=",")
hadoop_data_r_plot_matrix = np.loadtxt("fig6_link_util_hadoop.csv", delimiter=",")

# plot
fig, ax = plt.subplots(linewidth=2)

ax.plot(web_data_r_plot_matrix[:,0], web_data_r_plot_matrix[:,1], color="r", label="Web")
ax.plot(cache_data_r_plot_matrix[:,0], cache_data_r_plot_matrix[:,1], color="g", label="Cache")
ax.plot(hadoop_data_r_plot_matrix[:,0], hadoop_data_r_plot_matrix[:,1], color="b", label="Hadoop")

# labels
ax.set_xlim((0,100))
ax.set_xlabel("% Link Utilization")
ax.set_ylabel("CDF")

plt.legend(loc=4)
ax.get_xaxis().set_visible(True)
ax.get_yaxis().set_visible(True)
ax.xaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)
ax.yaxis.grid(True, linestyle='--', which='major', color='grey', alpha=.25)
ax.set_facecolor('white')
fig.set_size_inches(6, 3.5)
